# %% [markdown]
# <a href="https://colab.research.google.com/github/swapnilbpatil/Required-Notebook/blob/main/Forest_Type_Cover_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task1 :- Data loading and statistics**

# %%
import pandas as pd
from sklearn import preprocessing

# %%
dataset = pd.read_csv("path.csv")

# %%
dataset.head()
# Out:
#    Id  Elevation  Aspect  ...  Soil_Type39  Soil_Type40  Cover_Type
# 0   1       2596      51  ...            0            0           5
# 1   2       2590      56  ...            0            0           5
# 2   3       2804     139  ...            0            0           2
# 3   4       2785     155  ...            0            0           2
# 4   5       2595      45  ...            0            0           5
#
# [5 rows x 56 columns]

# %%
dataset.shape
# Out:
# (15120, 56)

# %%
dataset = dataset.drop('Id',axis=1)

# %%
dataset.shape
# Out:
# (15120, 55)

# %%
dataset.describe()
# Out:
#           Elevation        Aspect  ...   Soil_Type40    Cover_Type
# count  15120.000000  15120.000000  ...  15120.000000  15120.000000
# mean    2749.322553    156.676653  ...      0.030357      4.000000
# std      417.678187    110.085801  ...      0.171574      2.000066
# min     1863.000000      0.000000  ...      0.000000      1.000000
# 25%     2376.000000     65.000000  ...      0.000000      2.000000
# 50%     2752.000000    126.000000  ...      0.000000      4.000000
# 75%     3104.000000    261.000000  ...      0.000000      6.000000
# max     3849.000000    360.000000  ...      1.000000      7.000000
#
# [8 rows x 55 columns]

# %%
dataset.shape
# Out:
# (15120, 55)

# %% [markdown]
# # **Task2 :- Exploratory Data Analysis**

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
dataset.head()
# Out:
#    Elevation  Aspect  Slope  ...  Soil_Type39  Soil_Type40  Cover_Type
# 0       2596      51      3  ...            0            0           5
# 1       2590      56      2  ...            0            0           5
# 2       2804     139      9  ...            0            0           2
# 3       2785     155     18  ...            0            0           2
# 4       2595      45      2  ...            0            0           5
#
# [5 rows x 55 columns]

# %%
dataset.shape
# Out:
# (15120, 55)

# %%
dataset.columns
# Out:
# Index(['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
#        'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
#        'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points', 'Wilderness_Area1',
#        'Wilderness_Area2', 'Wilderness_Area3', 'Wilderness_Area4',
#        'Soil_Type1', 'Soil_Type2', 'Soil_Type3', 'Soil_Type4', 'Soil_Type5',
#        'Soil_Type6', 'Soil_Type7', 'Soil_Type8', 'Soil_Type9', 'Soil_Type10',
#        'Soil_Type11', 'Soil_Type12', 'Soil_Type13', 'Soil_Type14',
#        'Soil_Type15', 'Soil_Type16', 'Soil_Type17', 'Soil_Type18',
#        'Soil_Type19', 'Soil_Type20', 'Soil_Type21', 'Soil_Type22',
#        'Soil_Type23', 'Soil_Type24', 'Soil_Type25', 'Soil_Type26',
#        'Soil_Type27', 'Soil_Type28', 'Soil_Type29', 'Soil_Type30',
#        'Soil_Type31', 'Soil_Type32', 'Soil_Type33', 'Soil_Type34',
#        'Soil_Type35', 'Soil_Type36', 'Soil_Type37', 'Soil_Type38',
#        'Soil_Type39', 'Soil_Type40', 'Cover_Type'],
#       dtype='object')

# %%
col = 'Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology', 'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways','Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm', 'Horizontal_Distance_To_Fire_Points', 'Wilderness_Area1', 'Wilderness_Area2', 'Wilderness_Area3', 'Wilderness_Area4', 'Soil_Type1', 'Soil_Type2', 'Soil_Type3', 'Soil_Type4', 'Soil_Type5', 'Soil_Type6', 'Soil_Type7', 'Soil_Type8', 'Soil_Type9', 'Soil_Type10', 'Soil_Type11', 'Soil_Type12', 'Soil_Type13', 'Soil_Type14', 'Soil_Type15', 'Soil_Type16', 'Soil_Type17', 'Soil_Type18','Soil_Type19', 'Soil_Type20', 'Soil_Type21', 'Soil_Type22', 'Soil_Type23', 'Soil_Type24', 'Soil_Type25', 'Soil_Type26', 'Soil_Type27', 'Soil_Type28', 'Soil_Type29', 'Soil_Type30', 'Soil_Type31', 'Soil_Type32', 'Soil_Type33', 'Soil_Type34', 'Soil_Type35', 'Soil_Type36', 'Soil_Type37', 'Soil_Type38', 'Soil_Type39', 'Soil_Type40', 'Cover_Type'

# %%
size =len(col)
size
# Out:
# 55

# %%
dataset.shape
# Out:
# (15120, 55)

# %%
X = dataset['Cover_Type']

# %%
X
# Out:
# 0        5
# 1        5
# 2        2
# 3        2
# 4        5
#         ..
# 15115    3
# 15116    3
# 15117    3
# 15118    3
# 15119    3
# Name: Cover_Type, Length: 15120, dtype: int64

# %%
y = dataset.iloc[:, :-1]

# %%
y
# Out:
#        Elevation  Aspect  Slope  ...  Soil_Type38  Soil_Type39  Soil_Type40
# 0           2596      51      3  ...            0            0            0
# 1           2590      56      2  ...            0            0            0
# 2           2804     139      9  ...            0            0            0
# 3           2785     155     18  ...            0            0            0
# 4           2595      45      2  ...            0            0            0
# ...          ...     ...    ...  ...          ...          ...          ...
# 15115       2607     243     23  ...            0            0            0
# 15116       2603     121     19  ...            0            0            0
# 15117       2492     134     25  ...            0            0            0
# 15118       2487     167     28  ...            0            0            0
# 15119       2475     197     34  ...            0            0            0
#
# [15120 rows x 54 columns]

# %%
ax = sns.violinplot(data = dataset)

# %%
dataset.shape
# Out:
# (15120, 55)

# %% [markdown]
# # **Task3 :- Closer look towards relationship between different variables**

# %%
import numpy
upper_threshold = 0.5
lower_threshold = -0.5

# %%
subset_train = dataset.iloc[:, :10]

# %%
subset_train
# Out:
#        Elevation  Aspect  ...  Hillshade_3pm  Horizontal_Distance_To_Fire_Points
# 0           2596      51  ...            148                                6279
# 1           2590      56  ...            151                                6225
# 2           2804     139  ...            135                                6121
# 3           2785     155  ...            122                                6211
# 4           2595      45  ...            150                                6172
# ...          ...     ...  ...            ...                                 ...
# 15115       2607     243  ...            214                                1282
# 15116       2603     121  ...             91                                1325
# 15117       2492     134  ...             83                                1187
# 15118       2487     167  ...            119                                 932
# 15119       2475     197  ...            164                                 914
#
# [15120 rows x 10 columns]

# %%
data_corr = subset_train.corr()

# %%
data_corr
# Out:
#                                     Elevation  ...  Horizontal_Distance_To_Fire_Points
# Elevation                            1.000000  ...                            0.443563
# Aspect                              -0.011096  ...                           -0.052169
# Slope                               -0.312640  ...                           -0.239527
# Horizontal_Distance_To_Hydrology     0.412712  ...                            0.158817
# Vertical_Distance_To_Hydrology       0.122092  ...                           -0.015048
# Horizontal_Distance_To_Roadways      0.578659  ...                            0.486386
# Hillshade_9am                        0.097900  ...                            0.078144
# Hillshade_Noon                       0.215782  ...                            0.122098
# Hillshade_3pm                        0.089518  ...                            0.043162
# Horizontal_Distance_To_Fire_Points   0.443563  ...                            1.000000
#
# [10 rows x 10 columns]

# %%
sns.heatmap(data=data_corr)

# %%
correlation = data_corr.unstack().sort_values(kind='quicksort')

# %%
correlation
# Out:
# Hillshade_3pm                       Hillshade_9am                        -0.779965
# Hillshade_9am                       Hillshade_3pm                        -0.779965
# Hillshade_Noon                      Slope                                -0.612613
# Slope                               Hillshade_Noon                       -0.612613
# Aspect                              Hillshade_9am                        -0.593997
#                                                                             ...
# Horizontal_Distance_To_Hydrology    Horizontal_Distance_To_Hydrology      1.000000
# Slope                               Slope                                 1.000000
# Aspect                              Aspect                                1.000000
# Hillshade_3pm                       Hillshade_3pm                         1.000000
# Horizontal_Distance_To_Fire_Points  Horizontal_Distance_To_Fire_Points    1.000000
# Length: 100, dtype: float64

# %%
corr_var_list_1 = correlation[(correlation > upper_threshold) | (correlation < lower_threshold)]

# %%
corr_var_list_1
# Out:
# Hillshade_3pm                       Hillshade_9am                        -0.779965
# Hillshade_9am                       Hillshade_3pm                        -0.779965
# Hillshade_Noon                      Slope                                -0.612613
# Slope                               Hillshade_Noon                       -0.612613
# Aspect                              Hillshade_9am                        -0.593997
# Hillshade_9am                       Aspect                               -0.593997
# Horizontal_Distance_To_Roadways     Elevation                             0.578659
# Elevation                           Horizontal_Distance_To_Roadways       0.578659
# Hillshade_Noon                      Hillshade_3pm                         0.614526
# Hillshade_3pm                       Hillshade_Noon                        0.614526
#                                     Aspect                                0.635022
# Aspect                              Hillshade_3pm                         0.635022
# Vertical_Distance_To_Hydrology      Horizontal_Distance_To_Hydrology      0.652142
# Horizontal_Distance_To_Hydrology    Vertical_Distance_To_Hydrology        0.652142
# Elevation                           Elevation                             1.000000
# Hillshade_Noon                      Hillshade_Noon                        1.000000
# Hillshade_9am                       Hillshade_9am                         1.000000
# Horizontal_Distance_To_Roadways     Horizontal_Distance_To_Roadways       1.000000
# Vertical_Distance_To_Hydrology      Vertical_Distance_To_Hydrology        1.000000
# Horizontal_Distance_To_Hydrology    Horizontal_Distance_To_Hydrology      1.000000
# Slope                               Slope                                 1.000000
# Aspect                              Aspect                                1.000000
# Hillshade_3pm                       Hillshade_3pm                         1.000000
# Horizontal_Distance_To_Fire_Points  Horizontal_Distance_To_Fire_Points    1.000000
# dtype: float64

# %%
corr_var_list = corr_var_list_1[corr_var_list_1 != 1]

# %%
corr_var_list
# Out:
# Hillshade_3pm                     Hillshade_9am                      -0.779965
# Hillshade_9am                     Hillshade_3pm                      -0.779965
# Hillshade_Noon                    Slope                              -0.612613
# Slope                             Hillshade_Noon                     -0.612613
# Aspect                            Hillshade_9am                      -0.593997
# Hillshade_9am                     Aspect                             -0.593997
# Horizontal_Distance_To_Roadways   Elevation                           0.578659
# Elevation                         Horizontal_Distance_To_Roadways     0.578659
# Hillshade_Noon                    Hillshade_3pm                       0.614526
# Hillshade_3pm                     Hillshade_Noon                      0.614526
#                                   Aspect                              0.635022
# Aspect                            Hillshade_3pm                       0.635022
# Vertical_Distance_To_Hydrology    Horizontal_Distance_To_Hydrology    0.652142
# Horizontal_Distance_To_Hydrology  Vertical_Distance_To_Hydrology      0.652142
# dtype: float64

# %% [markdown]
# # **Task4 :- Data Cleaning , Data preparation ...getting towards feature selection**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
# Identify the unnecessary columns and remove it 
dataset.drop(columns=['Soil_Type7', 'Soil_Type15'], inplace=True)

# %%
dataset.head()
# Out:
#    Elevation  Aspect  Slope  ...  Soil_Type39  Soil_Type40  Cover_Type
# 0       2596      51      3  ...            0            0           5
# 1       2590      56      2  ...            0            0           5
# 2       2804     139      9  ...            0            0           2
# 3       2785     155     18  ...            0            0           2
# 4       2595      45      2  ...            0            0           5
#
# [5 rows x 53 columns]

# %%
dataset.shape
# Out:
# (15120, 53)

# %%
X = dataset.iloc[:, :-1]

# %%
X
# Out:
#        Elevation  Aspect  Slope  ...  Soil_Type38  Soil_Type39  Soil_Type40
# 0           2596      51      3  ...            0            0            0
# 1           2590      56      2  ...            0            0            0
# 2           2804     139      9  ...            0            0            0
# 3           2785     155     18  ...            0            0            0
# 4           2595      45      2  ...            0            0            0
# ...          ...     ...    ...  ...          ...          ...          ...
# 15115       2607     243     23  ...            0            0            0
# 15116       2603     121     19  ...            0            0            0
# 15117       2492     134     25  ...            0            0            0
# 15118       2487     167     28  ...            0            0            0
# 15119       2475     197     34  ...            0            0            0
#
# [15120 rows x 52 columns]

# %%
y = dataset.iloc[:, -1:]

# %%
y
# Out:
#        Cover_Type
# 0               5
# 1               5
# 2               2
# 3               2
# 4               5
# ...           ...
# 15115           3
# 15116           3
# 15117           3
# 15118           3
# 15119           3
#
# [15120 rows x 1 columns]

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
X_train
# Out:
#        Elevation  Aspect  Slope  ...  Soil_Type38  Soil_Type39  Soil_Type40
# 7366        3367     294      9  ...            1            0            0
# 4936        2221     110     26  ...            0            0            0
# 5777        3372     265      6  ...            0            0            1
# 10724       2555     121     10  ...            0            0            0
# 9412        3428       3     19  ...            0            1            0
# ...          ...     ...    ...  ...          ...          ...          ...
# 13123       2391      72     10  ...            0            0            0
# 3264        2136      39     28  ...            0            0            0
# 9845        3515     158     27  ...            0            0            0
# 10799       2575      80     35  ...            0            0            0
# 2732        2738     304      9  ...            0            0            0
#
# [12096 rows x 52 columns]

# %%
size=40

# %%
scaler = StandardScaler()

# %%
X_train_temp = scaler.fit_transform(X_train.iloc[:, 0:size])

# %%
X_train_temp
# Out:
# array([[ 1.47745234,  1.24641777, -0.88630754, ..., -0.05687386,
#         -0.03151267, -0.02572573],
#        [-1.27154731, -0.42495364,  1.12720615, ..., -0.05687386,
#         -0.03151267, -0.02572573],
#        [ 1.48944623,  0.9829951 , -1.24163349, ..., -0.05687386,
#         -0.03151267, -0.02572573],
#        ...,
#        [ 1.83247149,  0.0110563 ,  1.24564814, ..., -0.05687386,
#         -0.03151267, -0.02572573],
#        [-0.42237988, -0.69745984,  2.19318399, ..., -0.05687386,
#         -0.03151267, -0.02572573],
#        [-0.03137906,  1.33725317, -0.88630754, ..., -0.05687386,
#         -0.03151267, -0.02572573]])

# %%
X_test_temp = scaler.fit_transform(X_test.iloc[:, 0:size])

# %%
X_train1
# Out:
# array([[ 1.47745234e+00,  1.24641777e+00, -8.86307540e-01, ...,
#          4.32438732e+00, -2.12795006e-01, -1.73632330e-01],
#        [-1.27154731e+00, -4.24953635e-01,  1.12720615e+00, ...,
#         -2.31246631e-01, -2.12795006e-01, -1.73632330e-01],
#        [ 1.48944623e+00,  9.82995102e-01, -1.24163349e+00, ...,
#         -2.31246631e-01, -2.12795006e-01,  5.75929610e+00],
#        ...,
#        [ 3.51500000e+03,  1.58000000e+02,  2.70000000e+01, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 2.57500000e+03,  8.00000000e+01,  3.50000000e+01, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 2.73800000e+03,  3.04000000e+02,  9.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
X_train1 = np.concatenate((X_train_temp, X_train.iloc[:,size:]), axis=1)

# %%
X_test1
# Out:
# array([[-1.27394609e+00, -1.26063934e+00, -5.30981594e-01, ...,
#         -2.31246631e-01, -2.12795006e-01, -1.73632330e-01],
#        [-1.46824711e+00, -3.43201773e-01, -7.67865558e-01, ...,
#         -2.31246631e-01, -2.12795006e-01, -1.73632330e-01],
#        [-1.10123407e+00, -4.34037175e-01,  1.12720615e+00, ...,
#         -2.31246631e-01, -2.12795006e-01, -1.73632330e-01],
#        ...,
#        [ 3.79200000e+03,  3.42000000e+02,  1.20000000e+01, ...,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#        [ 2.53900000e+03,  1.90000000e+01,  9.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 2.33200000e+03,  1.14000000e+02,  1.60000000e+01, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
X_test1 = np.concatenate((X_test_temp, X_test.iloc[:,size:]), axis=1)

# %%
X_test1
# Out:
# array([[-1.24141981, -1.25623284, -0.53858143, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.43394781, -0.33849182, -0.77398944, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.07028382, -0.42935727,  1.10927458, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 2.49504948,  1.68780765, -0.53858143, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.48319227, -1.24714629, -0.89169344, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.97520826, -0.38392454, -0.06776543, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
scaled_features_train_df = pd.DataFrame(X_train1, index= X_train.index, columns=X_train.columns)

# %%
scaled_features_train_df
# Out:
#        Elevation    Aspect     Slope  ...  Soil_Type38  Soil_Type39  Soil_Type40
# 7366    1.477452  1.246418 -0.886308  ...          1.0          0.0          0.0
# 4936   -1.271547 -0.424954  1.127206  ...          0.0          0.0          0.0
# 5777    1.489446  0.982995 -1.241633  ...          0.0          0.0          1.0
# 10724  -0.470355 -0.325035 -0.767866  ...          0.0          0.0          0.0
# 9412    1.623778 -1.396892  0.298112  ...          0.0          1.0          0.0
# ...          ...       ...       ...  ...          ...          ...          ...
# 13123  -0.863755 -0.770128 -0.767866  ...          0.0          0.0          0.0
# 3264   -1.475443 -1.069885  1.364090  ...          0.0          0.0          0.0
# 9845    1.832471  0.011056  1.245648  ...          0.0          0.0          0.0
# 10799  -0.422380 -0.697460  2.193184  ...          0.0          0.0          0.0
# 2732   -0.031379  1.337253 -0.886308  ...          0.0          0.0          0.0
#
# [12096 rows x 52 columns]

# %%
scaled_features_test_df = pd.DataFrame(X_test1, index= X_test.index, columns=X_train.columns)
scaled_features_test_df
# Out:
#        Elevation    Aspect     Slope  ...  Soil_Type38  Soil_Type39  Soil_Type40
# 4428   -1.241420 -1.256233 -0.538581  ...          0.0          0.0          0.0
# 12399  -1.433948 -0.338492 -0.773989  ...          0.0          0.0          0.0
# 4647   -1.070284 -0.429357  1.109275  ...          0.0          0.0          0.0
# 5953   -0.944309 -0.583829 -0.420877  ...          0.0          0.0          0.0
# 2946   -1.887934  1.733240 -0.420877  ...          0.0          0.0          0.0
# ...          ...       ...       ...  ...          ...          ...          ...
# 637    -0.138543  1.733240 -1.244805  ...          0.0          0.0          0.0
# 6352    1.028509 -0.592915 -0.303173  ...          0.0          0.0          0.0
# 9687    2.495049  1.687808 -0.538581  ...          0.0          0.0          1.0
# 13638  -0.483192 -1.247146 -0.891693  ...          0.0          0.0          0.0
# 13010  -0.975208 -0.383925 -0.067765  ...          0.0          0.0          0.0
#
# [3024 rows x 52 columns]

# %% [markdown]
# # **Task 5 :- Feature Selection using Select percentile**

# %%
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import f_classif

# %%
skb = SelectPercentile(score_func=f_classif,percentile=90)

# %%
predictors = skb.fit_transform(X_train1,Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
scores = list(skb.scores_)

# %%
scores
# Out:
# [13023.207161059043,
#  39.93804878679793,
#  245.77338365524932,
#  311.63976262801697,
#  64.99304235667877,
#  957.6194491637209,
#  296.3279790605302,
#  93.9837175516788,
#  154.4884049482673,
#  589.1073798669238,
#  732.9574360701072,
#  132.68798758168055,
#  354.4406095929273,
#  4079.8566264402657,
#  68.10135029279544,
#  114.68876198760478,
#  739.4045753044455,
#  204.09878923788267,
#  32.883492987790405,
#  135.59685570488523,
#  0.985985140425034,
#  6.851187978392043,
#  765.5916246752015,
#  43.84329270209905,
#  159.01554903261015,
#  160.9092796716333,
#  75.77164546263772,
#  16.588536581896886,
#  168.2668161789066,
#  26.187539656587152,
#  9.507330218530754,
#  23.308304963286215,
#  7.388530253265756,
#  174.27724668375276,
#  155.9581967610265,
#  50.548900690957424,
#  0.9859851404250111,
#  10.859615537342597,
#  3.2343180287021736,
#  3.584856785037161,
#  267.91306904375756,
#  294.69886261558895,
#  46.3393598383929,
#  95.72533013546699,
#  61.529165023580155,
#  5.670730270051452,
#  73.42683979384333,
#  5.921062393534824,
#  24.109510828533832,
#  651.3483512584286,
#  489.20621526594135,
#  320.4613523640596]

# %%
Features = scaled_features_train_df.columns

# %%
Features
# Out:
# Index(['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
#        'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
#        'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points', 'Wilderness_Area1',
#        'Wilderness_Area2', 'Wilderness_Area3', 'Wilderness_Area4',
#        'Soil_Type1', 'Soil_Type2', 'Soil_Type3', 'Soil_Type4', 'Soil_Type5',
#        'Soil_Type6', 'Soil_Type8', 'Soil_Type9', 'Soil_Type10', 'Soil_Type11',
#        'Soil_Type12', 'Soil_Type13', 'Soil_Type14', 'Soil_Type16',
#        'Soil_Type17', 'Soil_Type18', 'Soil_Type19', 'Soil_Type20',
#        'Soil_Type21', 'Soil_Type22', 'Soil_Type23', 'Soil_Type24',
#        'Soil_Type25', 'Soil_Type26', 'Soil_Type27', 'Soil_Type28',
#        'Soil_Type29', 'Soil_Type30', 'Soil_Type31', 'Soil_Type32',
#        'Soil_Type33', 'Soil_Type34', 'Soil_Type35', 'Soil_Type36',
#        'Soil_Type37', 'Soil_Type38', 'Soil_Type39', 'Soil_Type40'],
#       dtype='object')

# %%
dataframe = pd.DataFrame({'Features':Features,'Scores':scores})

# %%
dataframe
# Out:
#                               Features        Scores
# 0                            Elevation  13023.207161
# 1                               Aspect     39.938049
# 2                                Slope    245.773384
# 3     Horizontal_Distance_To_Hydrology    311.639763
# 4       Vertical_Distance_To_Hydrology     64.993042
# 5      Horizontal_Distance_To_Roadways    957.619449
# 6                        Hillshade_9am    296.327979
# 7                       Hillshade_Noon     93.983718
# 8                        Hillshade_3pm    154.488405
# 9   Horizontal_Distance_To_Fire_Points    589.107380
# 10                    Wilderness_Area1    732.957436
# 11                    Wilderness_Area2    132.687988
# 12                    Wilderness_Area3    354.440610
# 13                    Wilderness_Area4   4079.856626
# 14                          Soil_Type1     68.101350
# 15                          Soil_Type2    114.688762
# 16                          Soil_Type3    739.404575
# 17                          Soil_Type4    204.098789
# 18                          Soil_Type5     32.883493
# 19                          Soil_Type6    135.596856
# 20                          Soil_Type8      0.985985
# 21                          Soil_Type9      6.851188
# 22                         Soil_Type10    765.591625
# 23                         Soil_Type11     43.843293
# 24                         Soil_Type12    159.015549
# 25                         Soil_Type13    160.909280
# 26                         Soil_Type14     75.771645
# 27                         Soil_Type16     16.588537
# 28                         Soil_Type17    168.266816
# 29                         Soil_Type18     26.187540
# 30                         Soil_Type19      9.507330
# 31                         Soil_Type20     23.308305
# 32                         Soil_Type21      7.388530
# 33                         Soil_Type22    174.277247
# 34                         Soil_Type23    155.958197
# 35                         Soil_Type24     50.548901
# 36                         Soil_Type25      0.985985
# 37                         Soil_Type26     10.859616
# 38                         Soil_Type27      3.234318
# 39                         Soil_Type28      3.584857
# 40                         Soil_Type29    267.913069
# 41                         Soil_Type30    294.698863
# 42                         Soil_Type31     46.339360
# 43                         Soil_Type32     95.725330
# 44                         Soil_Type33     61.529165
# 45                         Soil_Type34      5.670730
# 46                         Soil_Type35     73.426840
# 47                         Soil_Type36      5.921062
# 48                         Soil_Type37     24.109511
# 49                         Soil_Type38    651.348351
# 50                         Soil_Type39    489.206215
# 51                         Soil_Type40    320.461352

# %%
dataframe=dataframe.sort_values(by='Scores',ascending=False)

# %%
dataframe
# Out:
#                               Features        scores
# 0                            Elevation  13023.207161
# 13                    Wilderness_Area4   4079.856626
# 5      Horizontal_Distance_To_Roadways    957.619449
# 22                         Soil_Type10    765.591625
# 16                          Soil_Type3    739.404575
# 10                    Wilderness_Area1    732.957436
# 49                         Soil_Type38    651.348351
# 9   Horizontal_Distance_To_Fire_Points    589.107380
# 50                         Soil_Type39    489.206215
# 12                    Wilderness_Area3    354.440610
# 51                         Soil_Type40    320.461352
# 3     Horizontal_Distance_To_Hydrology    311.639763
# 6                        Hillshade_9am    296.327979
# 41                         Soil_Type30    294.698863
# 40                         Soil_Type29    267.913069
# 2                                Slope    245.773384
# 17                          Soil_Type4    204.098789
# 33                         Soil_Type22    174.277247
# 28                         Soil_Type17    168.266816
# 25                         Soil_Type13    160.909280
# 24                         Soil_Type12    159.015549
# 34                         Soil_Type23    155.958197
# 8                        Hillshade_3pm    154.488405
# 19                          Soil_Type6    135.596856
# 11                    Wilderness_Area2    132.687988
# 15                          Soil_Type2    114.688762
# 43                         Soil_Type32     95.725330
# 7                       Hillshade_Noon     93.983718
# 26                         Soil_Type14     75.771645
# 46                         Soil_Type35     73.426840
# 14                          Soil_Type1     68.101350
# 4       Vertical_Distance_To_Hydrology     64.993042
# 44                         Soil_Type33     61.529165
# 35                         Soil_Type24     50.548901
# 42                         Soil_Type31     46.339360
# 23                         Soil_Type11     43.843293
# 1                               Aspect     39.938049
# 18                          Soil_Type5     32.883493
# 29                         Soil_Type18     26.187540
# 48                         Soil_Type37     24.109511
# 31                         Soil_Type20     23.308305
# 27                         Soil_Type16     16.588537
# 37                         Soil_Type26     10.859616
# 30                         Soil_Type19      9.507330
# 32                         Soil_Type21      7.388530
# 21                          Soil_Type9      6.851188
# 47                         Soil_Type36      5.921062
# 45                         Soil_Type34      5.670730
# 39                         Soil_Type28      3.584857
# 38                         Soil_Type27      3.234318
# 20                          Soil_Type8      0.985985
# 36                         Soil_Type25      0.985985

# %%
top_k_predictors = list(dataframe['Features'][:predictors.shape[1]]) 
top_k_predictors
# Out:
# ['Elevation',
#  'Wilderness_Area4',
#  'Horizontal_Distance_To_Roadways',
#  'Soil_Type10',
#  'Soil_Type3',
#  'Wilderness_Area1',
#  'Soil_Type38',
#  'Horizontal_Distance_To_Fire_Points',
#  'Soil_Type39',
#  'Wilderness_Area3',
#  'Soil_Type40',
#  'Horizontal_Distance_To_Hydrology',
#  'Hillshade_9am',
#  'Soil_Type30',
#  'Soil_Type29',
#  'Slope',
#  'Soil_Type4',
#  'Soil_Type22',
#  'Soil_Type17',
#  'Soil_Type13',
#  'Soil_Type12',
#  'Soil_Type23',
#  'Hillshade_3pm',
#  'Soil_Type6',
#  'Wilderness_Area2',
#  'Soil_Type2',
#  'Soil_Type32',
#  'Hillshade_Noon',
#  'Soil_Type14',
#  'Soil_Type35',
#  'Soil_Type1',
#  'Vertical_Distance_To_Hydrology',
#  'Soil_Type33',
#  'Soil_Type24',
#  'Soil_Type31',
#  'Soil_Type11',
#  'Aspect',
#  'Soil_Type5',
#  'Soil_Type18',
#  'Soil_Type37',
#  'Soil_Type20',
#  'Soil_Type16',
#  'Soil_Type26',
#  'Soil_Type19',
#  'Soil_Type21',
#  'Soil_Type9']

# %% [markdown]
# # **Task6 :- Effect of feature selection on model prediction**

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score

# %%
clf = OneVsRestClassifier(LogisticRegression())
clf1 = LogisticRegression()

# %%
model_fit_all_features = clf1.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
predictions_all_features = clf1.predict(X_test)

# %%
score_all_features = accuracy_score(Y_test,predictions_all_features)

# %%
model_fit_top_features = clf.fit(scaled_features_train_df[top_k_predictors],Y_train)
predictions_top_features = model_fit_top_features.predict(scaled_features_test_df[top_k_predictors])
score_top_features = accuracy_score(Y_test, predictions_top_features)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
score_all_features
# Out:
# 0.5029761904761905

# %%
score_top_features
# Out:
# 0.6736111111111112
